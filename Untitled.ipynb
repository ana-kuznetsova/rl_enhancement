# %%
import soundfile as sndfl
import sounddevice as snddev
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

# %%
##PARAMETERS##
FS = 44000

#STFT params
WIN_LEN = 512
HOP_SIZE = 256
MAX_LEN = 175249

# %%
def read(path, sr):
    file, sr = librosa.core.load(path, sr, mono=True)
    return file[:-1]

def generate_noisy(speech, noise, desired_snr):    
    #calculate energies
    E_speech = np.sum(np.power(speech, 2))
    E_noise = np.sum(np.power(noise, 2))
    
    #calculate b coeff
    b = np.sqrt((E_speech/(np.power(10, (desired_snr/10))))/E_noise)
    print('b coeff: ', b)
    
    return speech + b*noise

def write(file_name, signal):
    librosa.output.write_wav(file_name, signal, 16000)

# %%
speech = read('test_audio/speech.wav', FS)
noise = read('test_audio/noise.wav', FS)

# %%
## SNRs = 0, 3, 6 Db
snr1 = 0
snr2 = 3
snr3 = -15

# %%
noisy1 = generate_noisy(speech, noise, snr1)
noisy2 = generate_noisy(speech, noise, snr2)
noisy3 = generate_noisy(speech, noise, snr3)

write('test_audio/noisy_0db.wav', noisy1)
write('test_audio/noisy_3db.wav', noisy2)
write('test_audio/noisy_6db.wav', noisy3)
# Out:
# b coeff:  0.17567498899827216
# b coeff:  0.1243683678830566
# b coeff:  0.9878930611608837

# %%
def STFT(x, win_len, hop_size, win_type='hann'):
    return librosa.core.stft(x, win_len, hop_size, win_len, win_type)

def calc_SNR(speech, noise):        
    E_speech = np.power(speech, 2)
    E_noise = np.power(noise, 2)
    return 10*np.log10(E_speech/E_noise)


def convert_SNR(speech, noise, target_snr):
    '''
    speech: wav input
    noise wav input
    '''
    E_speech = np.power(speech, 2)
    E_noise = np.power(noise, 2)  
    b = np.sqrt((E_speech/(np.power(10, (target_snr/10))))/E_noise)
    target = speech + b*noise
    
    if np.argwhere(np.isnan(target)):
        target = np.nan_to_num(target)
    return target
    
def IRM(speech, noise):
    '''
    Params:
        speech: stft matrix of speech signal
        noise: stft matrix of noise signal
    '''
    mask = np.power(10, calc_SNR(speech, noise)/10)/(np.power(10, SNR(speech, noise)/10) + 1)
    return mask

# %%
plots = [stft_speech0, stft_speech6]
names = ['Noisy SNR0', 'Noisy SNR6']

fig, ax = plt.subplots(2,1 , figsize=(9, 5))

ax = ax.ravel()
for i in range(2):
    ax[i].imshow(10*np.log10(np.abs(plots[i])), origin='lowest', 
                 aspect='auto', cmap='inferno')
    ax[i].set_title(names[i])

# %% [markdown]
# ## Data preproc pipeline

# %%
import os
from tqdm import tqdm

# %%
DATA_TRAIN_DIR = '/home/anakuz/data/docs/iu_courses/dl_for_speech/hw4/TIMIT_full/train/'

# %%
def collect_paths(train_dir):
    paths = []
    for dirs, subdirs, files in os.walk(train_dir):
        if len(dirs.split('/')) == 12:
            for file in files:
                if '.wav' in file:
                    paths.append(os.path.join(dirs, file))
    return paths

def pad_noise(speech, noise):
    '''
    Cuts noise vector if speech vec is shorter
    Adds noise if speech vector is longer
    Pads both till maxlen
    '''
    noise_len = noise.shape[0]
    speech_len = speech.shape[0]
    
    if speech_len > noise_len:
        repeat = speech_len//noise_len
        if repeat == 1:
            diff = speech_len - noise_len
            noise = np.concatenate((noise, noise[:diff]), axis=0)
        else:
            noise = np.tile(noise, repeat)
            diff = speech_len - noise.shape[0]
            noise = np.concatenate((noise, noise[:diff]))           
            
    elif speech_len < noise_len:
        noise = noise[:speech_len]  
    
    '''
    if speech_len < maxlen:
        speech = np.pad(speech, (0, maxlen - speech_len), mode='constant', constant_values=(0, 0))
    if noise.shape[0] < maxlen:
        noise = np.pad(noise, (0, maxlen - noise.shape[0]), mode='constant', constant_values=(0, 0))
    '''
    return noise

    
    

def calc_masks(speech_paths, noise_path, fs, win_len, hop_size, type='IRM'):
    masks = []
    noise = read(noise_path, fs)

    for p in tqdm(speech_paths):
        speech = read(p, fs)
        noise = pad_noise(speech, noise)
        stft_noise = STFT(noise, win_len, hop_size)
        stft_clean = STFT(speech, win_len, hop_size)
        masks.append(IRM(stft_clean, stft_noise))
    return masks

# %%
data_paths = collect_paths(DATA_TRAIN_DIR)

# %%
masks = calc_masks(data_paths, 'test_audio/noise.wav', FS, WIN_LEN, HOP_SIZE, MAX_LEN)
# Out:
#   0%|          | 0/4620 [00:00<?, ?it/s]
#
#
#   0%|          | 1/4620 [00:00<20:26,  3.77it/s]
# speech longer
#   0%|          | 2/4620 [00:00<21:27,  3.59it/s]
# speech longer
# speech shorter
# speech: 82791
# noise: 257947
#   0%|          | 3/4620 [00:00<17:33,  4.38it/s]
#
#
#   0%|          | 4/4620 [00:00<17:04,  4.50it/s]
# speech longer
#   0%|          | 5/4620 [00:01<17:14,  4.46it/s]
# speech longer
#   0%|          | 6/4620 [00:01<17:12,  4.47it/s]
# speech longer
#   0%|          | 7/4620 [00:01<18:50,  4.08it/s]
# speech longer
#   0%|          | 8/4620 [00:01<18:53,  4.07it/s]
# speech shorter
# speech: 201627
# noise: 206131
#   0%|          | 9/4620 [00:02<18:34,  4.14it/s]
# speech shorter
# speech: 160795
# noise: 201627
#   0%|          | 10/4620 [00:02<18:03,  4.25it/s]
# speech shorter
# speech: 160231
# noise: 160795
#   0%|          | 11/4620 [00:02<16:55,  4.54it/s]
# speech shorter
# speech: 93491
# noise: 160231
#   0%|          | 12/4620 [00:02<17:25,  4.41it/s]
# speech longer
#   0%|          | 13/4620 [00:03<18:01,  4.26it/s]
# speech longer
#   0%|          | 14/4620 [00:03<18:35,  4.13it/s]
# speech longer
#   0%|          | 15/4620 [00:03<18:15,  4.20it/s]
# speech shorter
# speech: 161358
# noise: 210919
#   0%|          | 16/4620 [00:03<18:32,  4.14it/s]
# speech longer
#   0%|          | 17/4620 [00:03<17:59,  4.27it/s]
# speech longer
# speech shorter
# speech: 139955
# noise: 183603
#   0%|          | 18/4620 [00:04<16:43,  4.59it/s]
#
#
#   0%|          | 19/4620 [00:04<15:09,  5.06it/s]
# speech shorter
# speech: 111515
# noise: 139955
# speech longer
#   0%|          | 20/4620 [00:04<14:36,  5.25it/s]
#
#
#   0%|          | 21/4620 [00:04<13:57,  5.49it/s]
#
#
#   0%|          | 22/4620 [00:04<12:17,  6.23it/s]
# speech shorter
# speech: 130943
# noise: 137983
# speech shorter
# speech: 87579
# noise: 130943
#   0%|          | 23/4620 [00:04<10:58,  6.98it/s]
#
#
#   1%|          | 24/4620 [00:05<11:16,  6.80it/s]
# speech shorter
# speech: 78003
# noise: 87579
# speech longer
#   1%|          | 25/4620 [00:05<11:10,  6.85it/s]
# speech shorter
# speech: 77439
# noise: 114611
#   1%|          | 26/4620 [00:05<14:23,  5.32it/s]
# speech longer
# speech shorter
# speech: 114047
# noise: 163891
#   1%|          | 27/4620 [00:05<13:23,  5.72it/s]
#
#
#   1%|          | 28/4620 [00:05<14:17,  5.35it/s]
#
#
#   1%|          | 29/4620 [00:05<13:11,  5.80it/s]
# speech longer
# speech shorter
# speech: 101659
# noise: 117147
#   1%|          | 30/4620 [00:06<12:05,  6.33it/s]
# speech shorter
# speech: 98843
# noise: 101659
#   1%|          | 31/4620 [00:06<13:50,  5.53it/s]
# speech longer
# speech shorter
# speech: 145023
# noise: 159103
#   1%|          | 32/4620 [00:06<13:46,  5.55it/s]
#
#
#   1%|          | 33/4620 [00:06<13:35,  5.62it/s]
# speech shorter
# speech: 121371
# noise: 145023
# speech longer
#   1%|          | 34/4620 [00:06<13:50,  5.52it/s]
#
#
#   1%|          | 35/4620 [00:07<15:54,  4.80it/s]
# speech longer
# speech shorter
# speech: 119963
# noise: 204723
#   1%|          | 36/4620 [00:07<14:45,  5.18it/s]
#
#
#   1%|          | 37/4620 [00:07<14:19,  5.33it/s]
# speech longer
#   1%|          | 38/4620 [00:07<15:32,  4.92it/s]
# speech longer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-540-3d6d954a16f5> in <module>
# ----> 1 masks = calc_masks(data_paths, 'test_audio/noise.wav', FS, WIN_LEN, HOP_SIZE, MAX_LEN)
#
# <ipython-input-539-491c9486df5d> in calc_masks(speech_paths, noise_path, fs, win_len, hop_size, type)
#      50
#      51     for p in tqdm(speech_paths):
# ---> 52         speech = read(p, fs)
#      53         noise = pad_noise(speech, noise)
#      54         stft_noise = STFT(noise, win_len, hop_size)
#
# <ipython-input-515-2b03c2df5dc9> in read(path, sr)
#       1 def read(path, sr):
# ----> 2     file, sr = librosa.core.load(path, sr, mono=True)
#       3     return file[:-1]
#       4
#       5 def generate_noisy(speech, noise, desired_snr):
#
# ~/miniconda3/envs/thesis/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     147
#     148     if sr is not None:
# --> 149         y = resample(y, sr_native, sr, res_type=res_type)
#     150
#     151     else:
#
# ~/miniconda3/envs/thesis/lib/python3.7/site-packages/librosa/core/audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     517         y_hat = scipy.signal.resample_poly(y, target_sr // gcd, orig_sr // gcd, axis=-1)
#     518     else:
# --> 519         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     520
#     521     if fix:
#
# ~/miniconda3/envs/thesis/lib/python3.7/site-packages/resampy/core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:
